# %%
#1. Create inheritance using MobilePhone as base class and Apple & Samsung as child class
class MobilePhone:
    def __init__(self, dual_sim, front_camera, rear_camera, ram, storage):
        self.screen_type = "Touch Screen"
        self.network_type = "4G/5G"
        self.dual_sim = dual_sim
        self.front_camera = front_camera
        self.rear_camera = rear_camera
        self.ram = ram
        self.storage = storage

    def phone_specs(self):
        print(f"Screen Type   : {self.screen_type}")
        print(f"Network Type  : {self.network_type}")
        print(f"Dual SIM      : {self.dual_sim}")
        print(f"Front Camera  : {self.front_camera}")
        print(f"Rear Camera   : {self.rear_camera}")
        print(f"RAM           : {self.ram}")
        print(f"Storage       : {self.storage}")
class Apple(MobilePhone):
    def __init__(self):
        # Apple typically doesn't support dual SIM (in older models)
        super().__init__(dual_sim=False, front_camera="12MP", rear_camera="48MP", ram="4GB", storage="64GB")
class Samsung(MobilePhone):
    def __init__(self):
        # Samsung often supports dual SIM
        super().__init__(dual_sim=True, front_camera="16MP", rear_camera="32MP", ram="3GB", storage="32GB")
print("Apple Phone Specs:")
apple_phone = Apple()
apple_phone.phone_specs()

print("\nSamsung Phone Specs:")
samsung_phone = Samsung()
samsung_phone.phone_specs()
# Out:
# Apple Phone Specs:
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 12MP
# Rear Camera   : 48MP
# RAM           : 4GB
# Storage       : 64GB
#
# Samsung Phone Specs:
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : True
# Front Camera  : 16MP
# Rear Camera   : 32MP
# RAM           : 3GB
# Storage       : 32GB

# %%
#2. Create basic mobile phone functionalities in the classes like: make_call, recieve_call, take_a_picture, etc.
class MobilePhone:
    def __init__(self, dual_sim, front_camera, rear_camera, ram, storage):
        self.screen_type = "Touch Screen"
        self.network_type = "4G/5G"
        self.dual_sim = dual_sim
        self.front_camera = front_camera
        self.rear_camera = rear_camera
        self.ram = ram
        self.storage = storage

    def phone_specs(self):
        print(f"Screen Type   : {self.screen_type}")
        print(f"Network Type  : {self.network_type}")
        print(f"Dual SIM      : {self.dual_sim}")
        print(f"Front Camera  : {self.front_camera}")
        print(f"Rear Camera   : {self.rear_camera}")
        print(f"RAM           : {self.ram}")
        print(f"Storage       : {self.storage}")

    def make_call(self, number):
        print(f"Dialing {number}...")

    def receive_call(self, from_contact):
        print(f"Incoming call from {from_contact}")

    def take_a_picture(self, camera_type="rear"):
        if camera_type == "front":
            print(f"Click! Photo taken with {self.front_camera} front camera.")
        elif camera_type == "rear":
            print(f"Click! Photo taken with {self.rear_camera} rear camera.")
        else:
            print("Invalid camera type. Choose 'front' or 'rear'.")

class Apple(MobilePhone):
    def __init__(self):
        super().__init__(dual_sim=False, front_camera="12MP", rear_camera="48MP", ram="4GB", storage="64GB")
class Samsung(MobilePhone):
    def __init__(self):
        super().__init__(dual_sim=True, front_camera="16MP", rear_camera="32MP", ram="3GB", storage="32GB")

print("=== Apple Phone ===")
iphone = Apple()
iphone.phone_specs()
iphone.make_call("9876543210")
iphone.receive_call("Mom")
iphone.take_a_picture("front")

print("\n=== Samsung Phone ===")
galaxy = Samsung()
galaxy.phone_specs()
galaxy.make_call("8123456789")
galaxy.receive_call("Friend")
galaxy.take_a_picture("rear")
# Out:
# === Apple Phone ===
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 12MP
# Rear Camera   : 48MP
# RAM           : 4GB
# Storage       : 64GB
# Dialing 9876543210...
# Incoming call from Mom
# Click! Photo taken with 12MP front camera.
#
# === Samsung Phone ===
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : True
# Front Camera  : 16MP
# Rear Camera   : 32MP
# RAM           : 3GB
# Storage       : 32GB
# Dialing 8123456789...
# Incoming call from Friend
# Click! Photo taken with 32MP rear camera.

# %%
#3. Use super() constructor for calling parent class’s constructor
class MobilePhone:
    def __init__(self, brand, dual_sim, front_camera, rear_camera, ram, storage):
        self.brand = brand
        self.screen_type = "Touch Screen"
        self.network_type = "4G/5G"
        self.dual_sim = dual_sim
        self.front_camera = front_camera
        self.rear_camera = rear_camera
        self.ram = ram
        self.storage = storage

    def phone_specs(self):
        print(f"Brand         : {self.brand}")
        print(f"Screen Type   : {self.screen_type}")
        print(f"Network Type  : {self.network_type}")
        print(f"Dual SIM      : {self.dual_sim}")
        print(f"Front Camera  : {self.front_camera}")
        print(f"Rear Camera   : {self.rear_camera}")
        print(f"RAM           : {self.ram}")
        print(f"Storage       : {self.storage}")

class Apple(MobilePhone):
    def __init__(self):
        # Using super() to call the base class constructor
        super().__init__(
            brand="Apple",
            dual_sim=False,
            front_camera="12MP",
            rear_camera="48MP",
            ram="4GB",
            storage="128GB"
        )

class Samsung(MobilePhone):
    def __init__(self):
        # Using super() to call the base class constructor
        super().__init__(
            brand="Samsung",
            dual_sim=True,
            front_camera="16MP",
            rear_camera="32MP",
            ram="6GB",
            storage="64GB"
        )
iphone = Apple()
galaxy = Samsung()
print("=== Apple iPhone Specs ===")
iphone.phone_specs()
print("\n=== Samsung Galaxy Specs ===")
galaxy.phone_specs()
# Out:
# === Apple iPhone Specs ===
# Brand         : Apple
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 12MP
# Rear Camera   : 48MP
# RAM           : 4GB
# Storage       : 128GB
#
# === Samsung Galaxy Specs ===
# Brand         : Samsung
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : True
# Front Camera  : 16MP
# Rear Camera   : 32MP
# RAM           : 6GB
# Storage       : 64GB

# %%
#4. Make some objects of Apple class with different properties
class MobilePhone:
    def __init__(self, brand, dual_sim, front_camera, rear_camera, ram, storage):
        self.brand = brand
        self.screen_type = "Touch Screen"
        self.network_type = "4G/5G"
        self.dual_sim = dual_sim
        self.front_camera = front_camera
        self.rear_camera = rear_camera
        self.ram = ram
        self.storage = storage

    def phone_specs(self):
        print(f"Brand         : {self.brand}")
        print(f"Screen Type   : {self.screen_type}")
        print(f"Network Type  : {self.network_type}")
        print(f"Dual SIM      : {self.dual_sim}")
        print(f"Front Camera  : {self.front_camera}")
        print(f"Rear Camera   : {self.rear_camera}")
        print(f"RAM           : {self.ram}")
        print(f"Storage       : {self.storage}")
        print("-" * 40)

class Apple(MobilePhone):
    def __init__(self, model, dual_sim, front_camera, rear_camera, ram, storage):
        self.model = model  # Custom model name
        super().__init__("Apple", dual_sim, front_camera, rear_camera, ram, storage)

    def phone_specs(self):
        print(f"Model         : {self.model}")
        super().phone_specs()  # Call base method to print other specs

# %%
iphone_se = Apple("iPhone SE", False, "7MP", "12MP", "3GB", "64GB")
iphone_13 = Apple("iPhone 13", False, "12MP", "12MP", "4GB", "128GB")
iphone_14_pro = Apple("iPhone 14 Pro", False, "12MP", "48MP", "6GB", "256GB")
iphone_x = Apple("iPhone X", False, "7MP", "12MP", "3GB", "64GB")
iphone_se.phone_specs()
iphone_13.phone_specs()
iphone_14_pro.phone_specs()
iphone_x.phone_specs()
# Out:
# Model         : iPhone SE
# Brand         : Apple
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 7MP
# Rear Camera   : 12MP
# RAM           : 3GB
# Storage       : 64GB
# ----------------------------------------
# Model         : iPhone 13
# Brand         : Apple
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 12MP
# Rear Camera   : 12MP
# RAM           : 4GB
# Storage       : 128GB
# ----------------------------------------
# Model         : iPhone 14 Pro
# Brand         : Apple
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 12MP
# Rear Camera   : 48MP
# RAM           : 6GB
# Storage       : 256GB
# ----------------------------------------
# Model         : iPhone X
# Brand         : Apple
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 7MP
# Rear Camera   : 12MP
# RAM           : 3GB
# ...

# %%
#5. Make some objects of Samsung class with different properties
class MobilePhone:
    def __init__(self, brand, dual_sim, front_camera, rear_camera, ram, storage):
        self.brand = brand
        self.screen_type = "Touch Screen"
        self.network_type = "4G/5G"
        self.dual_sim = dual_sim
        self.front_camera = front_camera
        self.rear_camera = rear_camera
        self.ram = ram
        self.storage = storage

    def phone_specs(self):
        print(f"Brand         : {self.brand}")
        print(f"Screen Type   : {self.screen_type}")
        print(f"Network Type  : {self.network_type}")
        print(f"Dual SIM      : {self.dual_sim}")
        print(f"Front Camera  : {self.front_camera}")
        print(f"Rear Camera   : {self.rear_camera}")
        print(f"RAM           : {self.ram}")
        print(f"Storage       : {self.storage}")
        print("-" * 40)
class Samsung(MobilePhone):
    def __init__(self, model, dual_sim, front_camera, rear_camera, ram, storage):
        self.model = model
        super().__init__("Samsung", dual_sim, front_camera, rear_camera, ram, storage)

    def phone_specs(self):
        print(f"Model         : {self.model}")
        super().phone_specs()

# %%
galaxy_m13 = Samsung("Galaxy M13", True, "8MP", "50MP", "4GB", "64GB")
galaxy_s21 = Samsung("Galaxy S21", False, "10MP", "64MP", "8GB", "128GB")
galaxy_a32 = Samsung("Galaxy A32", True, "20MP", "64MP", "6GB", "128GB")
galaxy_z_flip = Samsung("Galaxy Z Flip", False, "12MP", "12MP", "8GB", "256GB")
galaxy_m13.phone_specs()
galaxy_s21.phone_specs()
galaxy_a32.phone_specs()
galaxy_z_flip.phone_specs()
# Out:
# Model         : Galaxy M13
# Brand         : Samsung
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : True
# Front Camera  : 8MP
# Rear Camera   : 50MP
# RAM           : 4GB
# Storage       : 64GB
# ----------------------------------------
# Model         : Galaxy S21
# Brand         : Samsung
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 10MP
# Rear Camera   : 64MP
# RAM           : 8GB
# Storage       : 128GB
# ----------------------------------------
# Model         : Galaxy A32
# Brand         : Samsung
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : True
# Front Camera  : 20MP
# Rear Camera   : 64MP
# RAM           : 6GB
# Storage       : 128GB
# ----------------------------------------
# Model         : Galaxy Z Flip
# Brand         : Samsung
# Screen Type   : Touch Screen
# Network Type  : 4G/5G
# Dual SIM      : False
# Front Camera  : 12MP
# Rear Camera   : 12MP
# ...
